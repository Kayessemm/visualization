# %%
#Data visualization and advocacy
#
# Data can persuade through three main forms of appeal:
    # Rational
    # Moral
    # Emotional   
# E.g., slave ship diagram presented to British parliament 
# by abolitionists during the 19th Century: mainly emotional and 
# moral appeal, supported by raw data on the inhuman crowdedness 

# As illustrated by art-pieces, e.g., one on AIDS, any visualization involves
# choices on who and what are excluded: whether these are quantitative or
# qualitative data.
# The diverse economies iceberg illustrates how much "underwater labour"
# goes into creating data visualization, and who are excluded from credit

# %%
# Live-coding for seaborn and other packages beyond matplotlib

# Import packages for Seaborn

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
# Laod tips dataset

tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#make line plot 

sns.lineplot(data=tips, # choose our dataset 
             x='total_bill', # define our x variable 
             y='tip') # define our y variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Use premade style
sns.lineplot(data=tips, # choose our dataset 
             x='total_bill', # define our x variable 
             y='tip') # define our y variable
sns.set_style('darkgrid')

# %%
# Add title and axis labels

tipgraph = sns.lineplot(data=tips, 
                        x='total_bill', 
                        y='tip')
tipgraph.set(title='Tips vs. Total Bill', 
             xlabel='Total Bill ($)', 
             ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
#change figure size 

fig = plt.subplots(figsize=(10, 3))

tipgraph = sns.lineplot(data=tips, 
                        x='total_bill', 
                        y='tip')
tipgraph.set(title='Tips vs. Total Bill', 
             xlabel='Total Bill ($)', 
             ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
# Change colour, marker style, and line style

fig = plt.subplots(figsize=(10, 3))
tipgraph = sns.lineplot(data=tips,
                         x='total_bill',
                         y='tip', 
                         color = 'hotpink', 
                         linestyle = '--', 
                         linewidth = 3, 
                         marker = 'o', 
                         markerfacecolor = 'indigo')

# %%
# Seaborn is helpful because it allows us to represent 
# variables differently in the same graph

tipgraph = sns.scatterplot(data=tips, x='total_bill',
                            y='tip', style = 'time', hue = 'day', 
                            palette = ['purple', 'hotpink', 'deepskyblue', 'yellowgreen'])
tipgraph.set(title='Tips vs. Total Bill', xlabel='Total Bill ($)', ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
# Pairplots are helpful visualizations possible in Seaborn

sns.pairplot( data = tips,
              hue = 'day')

# %%
# Relplots allo comparisons of specific levels within variables

daysplot = sns.relplot( data=tips, 
                       x="total_bill", 
                       y="tip", 
                       hue="sex", 
                       col="day", 
                       kind="scatter", 
                       col_wrap=2)

# %%
# How do the figures comparing student ratings based on perceived 
# gender of instructors differ?
    # One figure breaks down the ratings based on discipline, which helps
    # to visualize where genedered biases are more common; whereas the other
    # shows ratings in aggregate with bars for the margins of error that show
    # significant differences between perceived genders, but not between actual
    # genders

# %%
# Whereas static data visualization is a snapshot of data, dynamic data
# viz is interactive and can show multiple data stories in one

# Dynamic data viz is helpful to increase viewer engagement and allow 
# investigation of individual observations.
# BUT they may result in less focused messages/stories, they can be overwhelming,
# and they are difficult to share (usually need to be hosted on a website)

# %%
# Best practices for dynamic data viz include unique elements:
    # Interactive elements easy to navigate?
    # Accessible interactive elements?
    # How much time to interact with visualization?
    # **Do the interactive features actually help the visualization?**
    # Where are spatial elements, how many?
    # Are the retinal elements accessible (e.g., brightness, colour, patterning) 
    # Will the elements be fixed or changing?
# Types of changes: identity-preserving (maintained associations); 
# Transitional (some new associations);
# immediate (all new associations)

# %%
# Plotly is used for dynamic data visualization

# Import Plotly graph objects as "Graphic Objects"

import plotly.graph_objects as go # 'go' is 'graph objects’
x1 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

# %%
# Make the figure

graph = go.Figure()

# Choose plot type

graph.add_trace(go.Bar(x=x1, y=y1))

# %%
# Update layout to include titles

graph.update_layout(
    title="Pirate Scores",
    xaxis_title="Pirates",
    yaxis_title="Score"
)

# %%
# Save the plotly graph as an HTML and embed in webpage

graph.write_html("e:/1_DSI_Certificate/Visualization.html")

# %%
# Customize plotly graph

graph = go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers', #points for a scatter plot
                           marker=dict(
                               size=15,
                               color='hotpink',
                               opacity=1,
                               line=dict(width=5, color='purple'))
                           ))
graph.update_layout(
    title='Interactive Pirate Plot',
    xaxis_title='Pirates',
    yaxis_title='Scores',
    width=500, height=500
)

# %%
# Use wordclouds for qualitative visualization

# Import wordcloud package

from wordcloud import WordCloud
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
                 on_bad_lines='skip')

df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# ...

# %%
# Make simple word cloud with 'quote' variable

# Join text from each row from quote column into a string

text = " ".join(each for each in df.quote)

# generate wordcloud image

wordcloud = WordCloud(background_color="white",
                      colormap = 'inferno').generate(text)

# Use matplotlib syntax to put image in a figure

fig, ax = plt.subplots(figsize=(7,3))
ax.imshow(wordcloud,   
          interpolation='bilinear') #smooths image
ax.axis("off")
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %%
# Make Venn diagrams

# Import venn diagram package

from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# Define sets

A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

# %%
# Assign sets to either circle and modify the appearance

diagram = venn2_unweighted([A, B],
                           set_labels = ('Fruits', 'Pies'),
                           set_colors=("blue","red"),
                           alpha=0.5)
plt.show()
# Out:
# e:\1_DSI_Certificate\Visualization\visualization\visualization-env\Lib\site-packages\matplotlib_venn\_util.py:32: UserWarning:
#
# venn2_unweighted is deprecated. Use venn2 with the appropriate layout_algorithm instead.

# %%
# Add labels to the diagram

diagram = venn2_unweighted([A, B],
                           set_labels = ('Fruits', 'Pies'),
                           set_colors=("blue","red"),
                           alpha=0.5)

diagram.get_label_by_id("10").set_text("\n".join(A-B))

diagram.get_label_by_id("11").set_text("\n".join(A&B))

diagram.get_label_by_id("01").set_text("\n".join(B-A))
# Out:
# e:\1_DSI_Certificate\Visualization\visualization\visualization-env\Lib\site-packages\matplotlib_venn\_util.py:32: UserWarning:
#
# venn2_unweighted is deprecated. Use venn2 with the appropriate layout_algorithm instead.
